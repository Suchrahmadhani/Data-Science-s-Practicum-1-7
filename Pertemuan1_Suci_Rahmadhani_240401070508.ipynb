# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchrahmadhani/Data-Science-s-Practicum-1-7/blob/main/Pertemuan1_Suci_Rahmadhani_240401070508.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 1: Data Science
#
# ## Identitas Mahasiswa
#
# | Keterangan | Informasi |
# |------------|-----------|
# | **Nama** | Suci Rahmadhani |
# | **NIM** | 240401070508 |
# | **Kelas** | IF404 |
# | **Program Studi** | PJJ Informatika |
# | **Mata Kuliah** | Data Science |

# %% [markdown]
# # Tujuan Praktikum
#
# Pada praktikum pertama ini saya mulai mengenal lingkungan kerja yang digunakan dalam mata kuliah Data Science, yaitu Google Colab. Selain itu saya juga mempelajari dasar-dasar Python, seperti cara menampilkan output, membuat variabel, mengenal tipe data, menggunakan list, melakukan perulangan, dan membuat fungsi sederhana. Materi ini menjadi dasar sebelum mempelajari pengolahan data pada pertemuan berikutnya.

# %% [markdown]
# # Ringkasan Materi
#
# Pada pertemuan ini saya memahami bahwa Python merupakan bahasa pemrograman yang banyak digunakan dalam bidang Data Science karena sintaksnya mudah dipelajari dan memiliki banyak library pendukung. Saya juga mulai mengenal Google Colab sebagai tempat untuk menulis dan menjalankan kode Python secara langsung melalui browser.
#
# Selain itu, saya belajar mengenai penggunaan variabel, tipe data dasar, list, perulangan menggunakan `for`, serta cara membuat fungsi sederhana dengan `def`. Semua materi tersebut menjadi fondasi sebelum mempelajari analisis data menggunakan library Python.

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana

print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar

nama = "Suci Rahmadhani"      # String
angkatan = 2024               # Integer
ipk = 3.98                    # Float
aktif = True                  # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Suci Rahmadhani
# Angkatan  : 2024
# IPK       : 3.98
# Aktif     : True

# %%
# SEL 3: List dan perulangan

tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
# SEL 4: Fungsi sederhana

def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Suci Rahmadhani", "PJJ Informatika", 2024)

print(hasil)
# Out:
# Hai! Saya Suci Rahmadhani dari PJJ Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan
#
# Pada praktikum ini saya mempelajari dasar-dasar Python, seperti penggunaan variabel, tipe data, list, perulangan, dan fungsi sederhana.
#
# Temuan utama yang saya peroleh adalah Python memiliki sintaks yang mudah dipahami sehingga cocok digunakan sebagai bahasa pemrograman untuk Data Science.
#
# Keterbatasan pada praktikum ini adalah materi masih berfokus pada dasar-dasar Python dan belum menggunakan dataset maupun library seperti Pandas atau NumPy. Saya berharap pada pertemuan berikutnya dapat mulai mengolah data secara langsung.
